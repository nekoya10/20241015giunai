# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.DataFrame(np.random.randn(10,4).cumsum(axis=0),
             columns=['A', 'B', 'C', 'D'],
             index=np.arange(0,100,10)
             )
df.plot.line()
# Out:
# <Axes: >

# %%
fig, axes = plt.subplots(2, 1)
series = pd.Series(np.random.rand(16),
          index=list('abcdefghijklmnop'))
series.plot.bar(ax=axes[0], color='k', alpha=0.7)
series.plot.barh(ax=axes[1], color='k', alpha=0.7)
# Out:
# <Axes: >

# %%
df = pd.DataFrame(np.random.rand(6,4),
             index=['one','two','three','four','five','six'],
             columns=pd.Index(['A', 'B', 'C', 'D'],name='Genus'))
df
# Out:
# Genus         A         B         C         D
# one    0.535604  0.111535  0.622020  0.101826
# two    0.526460  0.170133  0.610699  0.583827
# three  0.329596  0.521777  0.166219  0.191244
# four   0.046703  0.265213  0.471965  0.343995
# five   0.143404  0.077338  0.254126  0.411693
# six    0.350224  0.808239  0.099201  0.047305

# %%
df.plot.bar()
# Out:
# <Axes: >

# %%
df.plot.barh(stacked=True, alpha=0.5)
# Out:
# <Axes: >

# %%
tips = pd.read_csv('tips.csv')
party_counts = pd.crosstab(tips['day'],tips['size'])
party_counts1 = party_counts.loc[:,2:5]
party_pcts = party_counts1.div(party_counts.sum(axis=1),axis=0)
party_pcts
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[47], line 2
#       1 tips = pd.read_csv('tips.csv')
# ----> 2 party_counts = pd.crosstab(tips['day'],tips['size'])
#       3 party_counts1 = party_counts.loc[:,2:5]
#       4 party_pcts = party_counts1.div(party_counts.sum(axis=1),axis=0)
#
# TypeError: 'DataFrame' object is not callable

# %%
party_pcst.plot.bar()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 party_pcst.plot.bar()
#
# NameError: name 'party_pcst' is not defined
